# %% [markdown]
# # EDA: Labels
#
# Use this notebook to inspect raw ratings, group agreement, and the 10 vs 8 comparison slices.

# %%
import pandas as pd
from cloud_aesthetics.utils.io import read_table

ratings = read_table('data/processed/ratings.parquet')
labels = read_table('data/processed/aggregated_labels.parquet')
ratings.head(), labels.head()
