# %% [markdown]
# # Embedding Space Exploration
#
# Use this notebook to inspect PCA or UMAP projections and nearest-neighbor structure.

# %%
from cloud_aesthetics.utils.io import read_table
from cloud_aesthetics.eval.analysis import compute_pca_projection

features = read_table('data/processed/features/features_v1.parquet')
compute_pca_projection(features).head()
